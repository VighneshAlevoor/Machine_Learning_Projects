# %% [markdown]
# <a href="https://colab.research.google.com/github/VighneshAlevoor/Machine_Learning_Projects/blob/master/Heart_disease_pred.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data= pd.read_csv('dataset.csv')
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 0   63    1   3       145   233    1  ...      0      2.3      0   0     1       1
# 1   37    1   2       130   250    0  ...      0      3.5      0   0     2       1
# 2   41    0   1       130   204    0  ...      0      1.4      2   0     2       1
# 3   56    1   1       120   236    0  ...      0      0.8      2   0     2       1
# 4   57    0   0       120   354    0  ...      1      0.6      2   0     2       1
#
# [5 rows x 14 columns]

# %%
data.describe()
# Out:
#               age         sex          cp  ...          ca        thal      target
# count  303.000000  303.000000  303.000000  ...  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  ...    0.729373    2.313531    0.544554
# std      9.082101    0.466011    1.032052  ...    1.022606    0.612277    0.498835
# min     29.000000    0.000000    0.000000  ...    0.000000    0.000000    0.000000
# 25%     47.500000    0.000000    0.000000  ...    0.000000    2.000000    0.000000
# 50%     55.000000    1.000000    1.000000  ...    0.000000    2.000000    1.000000
# 75%     61.000000    1.000000    2.000000  ...    1.000000    3.000000    1.000000
# max     77.000000    1.000000    3.000000  ...    4.000000    3.000000    1.000000
#
# [8 rows x 14 columns]

# %%
core = data.corr()
plt.figure(figsize=(15,15))
sns.heatmap(core,cmap='RdYlGn', cbar=True, annot = True)

# %%
data.hist(figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa2e8a68c18>,
# ...
#       dtype=object)

# %%
#check data is balanced or not
sns.set_style('whitegrid')
sns.countplot(x='target', data=data)

# %%
data = pd.get_dummies(data=data,drop_first=False, columns=['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal'])
data
# Out:
#      age  trestbps  chol  thalach  ...  thal_0  thal_1  thal_2  thal_3
# 0     63       145   233      150  ...       0       1       0       0
# 1     37       130   250      187  ...       0       0       1       0
# 2     41       130   204      172  ...       0       0       1       0
# 3     56       120   236      178  ...       0       0       1       0
# 4     57       120   354      163  ...       0       0       1       0
# ..   ...       ...   ...      ...  ...     ...     ...     ...     ...
# 298   57       140   241      123  ...       0       0       0       1
# 299   45       110   264      132  ...       0       0       0       1
# 300   68       144   193      141  ...       0       0       0       1
# 301   57       130   131      115  ...       0       0       0       1
# 302   57       130   236      174  ...       0       0       1       0
#
# [303 rows x 31 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
std=StandardScaler()
scale_col = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']
data[scale_col]=std.fit_transform(data[scale_col])
data
# Out:
#           age  trestbps      chol   thalach  ...  thal_0  thal_1  thal_2  thal_3
# 0    0.952197  0.763956 -0.256334  0.015443  ...       0       1       0       0
# 1   -1.915313 -0.092738  0.072199  1.633471  ...       0       0       1       0
# 2   -1.474158 -0.092738 -0.816773  0.977514  ...       0       0       1       0
# 3    0.180175 -0.663867 -0.198357  1.239897  ...       0       0       1       0
# 4    0.290464 -0.663867  2.082050  0.583939  ...       0       0       1       0
# ..        ...       ...       ...       ...  ...     ...     ...     ...     ...
# 298  0.290464  0.478391 -0.101730 -1.165281  ...       0       0       0       1
# 299 -1.033002 -1.234996  0.342756 -0.771706  ...       0       0       0       1
# 300  1.503641  0.706843 -1.029353 -0.378132  ...       0       0       0       1
# 301  0.290464 -0.092738 -2.227533 -1.515125  ...       0       0       0       1
# 302  0.290464 -0.092738 -0.198357  1.064975  ...       0       0       1       0
#
# ...

# %%
x=data.drop(['target'], axis = 1)
y = data['target']

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

# %%
knn_score=[]
for k in range(1,21):
  kn_classifier = KNeighborsClassifier(n_neighbors=k)
  score = cross_val_score(kn_classifier,x,y,cv=10)
  knn_score.append(score.mean())

# %%
score.mean()
# Out:
# 0.8243196143863551

# %%
plt.figure(figsize=(10,10))
plt.plot([k for k in range(1,21)], knn_score, color = 'red' )
for i in range(1,21):
  plt.text(i, knn_score[i-1],(i,knn_score[i-1]))
plt.xticks([k for k in range(1,21)])
plt.xlabel('Number of Neighbors (K)')
plt.ylabel('Scores')
plt.title('K Neighbors Classifier scores for different K values')
# Out:
# Text(0.5, 1.0, 'K Neighbors Classifier scores for different K values')

# %%
knn_classifier = KNeighborsClassifier(n_jobs=12)
score = cross_val_score(knn_classifier,x,y,cv=10)
score.mean()
# Out:
# 0.8338820912124584

# %%
#Random forest

random = RandomForestClassifier(n_estimators=10)
score = cross_val_score(random,x,y,cv = 10)
score.mean()
# Out:
# 0.8047348906192067
